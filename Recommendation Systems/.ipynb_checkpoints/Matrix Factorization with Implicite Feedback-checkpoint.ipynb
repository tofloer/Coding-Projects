# %%
# %pip install implicit
# Out:
# Collecting implicit
#   Downloading implicit-0.7.3-cp39-cp39-win_amd64.whl (694 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (4.62.3)
# Requirement already satisfied: scipy>=0.16 in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (1.7.1)
# Requirement already satisfied: threadpoolctl in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (2.2.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (1.20.3)
# Requirement already satisfied: colorama in c:\users\tobis\python\anaconda3\lib\site-packages (from tqdm>=4.27->implicit) (0.4.4)
# Installing collected packages: implicit
# Successfully installed implicit-0.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import implicit as imp
from implicit.als import AlternatingLeastSquares
from scipy.sparse import csr_matrix

# %%
df_movie = pd.read_csv(r"C:\Users\Tobis\Desktop\Implicit Recommendation System\movie\movie.csv")
df_rating = pd.read_csv(r"C:\Users\Tobis\Desktop\Implicit Recommendation System\rating\rating.csv")

# %%
print(df_rating.head())
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
print(df_movie.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Neue Spalte "implicit" erstellen
df_rating["implicit"] = (df_rating["rating"] >= 4).astype(int)
print(df_rating.head(10))
# Out:
#    userId  movieId  rating            timestamp  implicit
# 0       1        2     3.5  2005-04-02 23:53:47         0
# 1       1       29     3.5  2005-04-02 23:31:16         0
# 2       1       32     3.5  2005-04-02 23:33:39         0
# 3       1       47     3.5  2005-04-02 23:32:07         0
# 4       1       50     3.5  2005-04-02 23:29:40         0
# 5       1      112     3.5  2004-09-10 03:09:00         0
# 6       1      151     4.0  2004-09-10 03:08:54         1
# 7       1      223     4.0  2005-04-02 23:46:13         1
# 8       1      253     4.0  2005-04-02 23:35:40         1
# 9       1      260     4.0  2005-04-02 23:33:46         1

# %%
df_joined = df_rating.merge(
    df_movie,
    on="movieId",
    how="left"
)

print(df_joined.head())
# Out:
#    userId  movieId  rating            timestamp  implicit  \
# 0       1        2     3.5  2005-04-02 23:53:47         0
# 1       1       29     3.5  2005-04-02 23:31:16         0
# 2       1       32     3.5  2005-04-02 23:33:39         0
# 3       1       47     3.5  2005-04-02 23:32:07         0
# 4       1       50     3.5  2005-04-02 23:29:40         0
#
#                                                title  \
# 0                                     Jumanji (1995)
# 1  City of Lost Children, The (Cité des enfants p...
# 2          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                        Seven (a.k.a. Se7en) (1995)
# 4                         Usual Suspects, The (1995)
#
#                                    genres
# 0              Adventure|Children|Fantasy
# 1  Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 2                 Mystery|Sci-Fi|Thriller
# 3                        Mystery|Thriller
# 4                  Crime|Mystery|Thriller

# %%
print(df_joined)
# Out:
#           userId  movieId  rating            timestamp  implicit  \
# 0              1        2     3.5  2005-04-02 23:53:47         0
# 1              1       29     3.5  2005-04-02 23:31:16         0
# 2              1       32     3.5  2005-04-02 23:33:39         0
# 3              1       47     3.5  2005-04-02 23:32:07         0
# 4              1       50     3.5  2005-04-02 23:29:40         0
# ...          ...      ...     ...                  ...       ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00         1
# 20000259  138493    69526     4.5  2009-12-03 18:31:48         1
# 20000260  138493    69644     3.0  2009-12-07 18:10:57         0
# 20000261  138493    70286     5.0  2009-11-13 15:42:24         1
# 20000262  138493    71619     2.5  2009-10-17 20:25:36         0
#
#                                                       title  \
# 0                                            Jumanji (1995)
# 1         City of Lost Children, The (Cité des enfants p...
# 2                 Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                               Seven (a.k.a. Se7en) (1995)
# 4                                Usual Suspects, The (1995)
# ...                                                     ...
# 20000258                                          Up (2009)
# 20000259         Transformers: Revenge of the Fallen (2009)
# 20000260              Ice Age: Dawn of the Dinosaurs (2009)
# 20000261                                  District 9 (2009)
# 20000262      Coco Before Chanel (Coco avant Chanel) (2009)
#
#                                                      genres
# 0                                Adventure|Children|Fantasy
# 1                    Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 2                                   Mystery|Sci-Fi|Thriller
# 3                                          Mystery|Thriller
# 4                                    Crime|Mystery|Thriller
# ...                                                     ...
# 20000258                 Adventure|Animation|Children|Drama
# 20000259                       Action|Adventure|Sci-Fi|IMAX
# 20000260  Action|Adventure|Animation|Children|Comedy|Rom...
# 20000261                            Mystery|Sci-Fi|Thriller
# 20000262                                              Drama
#
# [20000263 rows x 7 columns]

# %%
df_positive = df_joined[df_joined["implicit"] == 1].copy()

# %%
print(df_positive)
# Out:
#           userId  movieId  rating            timestamp  implicit  \
# 6              1      151     4.0  2004-09-10 03:08:54         1
# 7              1      223     4.0  2005-04-02 23:46:13         1
# 8              1      253     4.0  2005-04-02 23:35:40         1
# 9              1      260     4.0  2005-04-02 23:33:46         1
# 10             1      293     4.0  2005-04-02 23:31:43         1
# ...          ...      ...     ...                  ...       ...
# 20000256  138493    66762     4.5  2009-10-17 18:50:08         1
# 20000257  138493    68319     4.5  2009-12-07 18:15:20         1
# 20000258  138493    68954     4.5  2009-11-13 15:42:00         1
# 20000259  138493    69526     4.5  2009-12-03 18:31:48         1
# 20000261  138493    70286     5.0  2009-11-13 15:42:24         1
#
#                                                       title  \
# 6                                            Rob Roy (1995)
# 7                                             Clerks (1994)
# 8         Interview with the Vampire: The Vampire Chroni...
# 9                 Star Wars: Episode IV - A New Hope (1977)
# 10        Léon: The Professional (a.k.a. The Professiona...
# ...                                                     ...
# 20000256                                       Paris (2008)
# 20000257                    X-Men Origins: Wolverine (2009)
# 20000258                                          Up (2009)
# 20000259         Transformers: Revenge of the Fallen (2009)
# 20000261                                  District 9 (2009)
#
#                                       genres
# 6                   Action|Drama|Romance|War
# 7                                     Comedy
# 8                               Drama|Horror
# 9                    Action|Adventure|Sci-Fi
# 10               Action|Crime|Drama|Thriller
# ...                                      ...
# 20000256                Comedy|Drama|Romance
# 20000257              Action|Sci-Fi|Thriller
# 20000258  Adventure|Animation|Children|Drama
# 20000259        Action|Adventure|Sci-Fi|IMAX
# 20000261             Mystery|Sci-Fi|Thriller
#
# [9995410 rows x 7 columns]

# %%
user_ids = df_rating["userId"].unique()
movie_ids = df_rating["movieId"].unique()

user_map = {u: i for i, u in enumerate(user_ids)}
movie_map = {m: i for i, m in enumerate(movie_ids)}

df_positive["user_idx"] = df_positive["userId"].map(user_map)
df_positive["movie_idx"] = df_positive["movieId"].map(movie_map)

# %%
max(df_rating["movieId"])
# Out:
# 131262

# %%
print(df_positive)
# Out:
#           userId  movieId  rating            timestamp  implicit  \
# 6              1      151     4.0  2004-09-10 03:08:54         1
# 7              1      223     4.0  2005-04-02 23:46:13         1
# 8              1      253     4.0  2005-04-02 23:35:40         1
# 9              1      260     4.0  2005-04-02 23:33:46         1
# 10             1      293     4.0  2005-04-02 23:31:43         1
# ...          ...      ...     ...                  ...       ...
# 20000256  138493    66762     4.5  2009-10-17 18:50:08         1
# 20000257  138493    68319     4.5  2009-12-07 18:15:20         1
# 20000258  138493    68954     4.5  2009-11-13 15:42:00         1
# 20000259  138493    69526     4.5  2009-12-03 18:31:48         1
# 20000261  138493    70286     5.0  2009-11-13 15:42:24         1
#
#                                                       title  \
# 6                                            Rob Roy (1995)
# 7                                             Clerks (1994)
# 8         Interview with the Vampire: The Vampire Chroni...
# 9                 Star Wars: Episode IV - A New Hope (1977)
# 10        Léon: The Professional (a.k.a. The Professiona...
# ...                                                     ...
# 20000256                                       Paris (2008)
# 20000257                    X-Men Origins: Wolverine (2009)
# 20000258                                          Up (2009)
# 20000259         Transformers: Revenge of the Fallen (2009)
# 20000261                                  District 9 (2009)
#
#                                       genres  user_idx  movie_idx
# 6                   Action|Drama|Romance|War         0          6
# 7                                     Comedy         0          7
# 8                               Drama|Horror         0          8
# 9                    Action|Adventure|Sci-Fi         0          9
# 10               Action|Crime|Drama|Thriller         0         10
# ...                                      ...       ...        ...
# 20000256                Comedy|Drama|Romance    138492      11011
# 20000257              Action|Sci-Fi|Thriller    138492       1036
# 20000258  Adventure|Animation|Children|Drama    138492       1814
# 20000259        Action|Adventure|Sci-Fi|IMAX    138492       1037
# 20000261             Mystery|Sci-Fi|Thriller    138492       1818
#
# [9995410 rows x 9 columns]

# %%
user_item = csr_matrix(
    (
        df_positive["implicit"],
        (
            df_positive["userId"],
            df_positive["movieId"]
        )
    )
)
print(user_item)
# Out:
#   (1, 151)	1
#   (1, 223)	1
#   (1, 253)	1
#   (1, 260)	1
#   (1, 293)	1
#   (1, 296)	1
#   (1, 318)	1
#   (1, 541)	1
#   (1, 1036)	1
#   (1, 1079)	1
#   (1, 1090)	1
#   (1, 1097)	1
#   (1, 1196)	1
#   (1, 1198)	1
#   (1, 1200)	1
#   (1, 1214)	1
#   (1, 1215)	1
#   (1, 1219)	1
#   (1, 1240)	1
#   (1, 1249)	1
#   (1, 1258)	1
#   (1, 1259)	1
#   (1, 1266)	1
#   (1, 1278)	1
#   (1, 1321)	1
#   :	:
#   (138493, 48516)	1
#   (138493, 48780)	1
#   (138493, 49651)	1
#   (138493, 51662)	1
#   (138493, 51884)	1
#   (138493, 52579)	1
#   (138493, 52975)	1
#   (138493, 53123)	1
#   (138493, 53322)	1
#   (138493, 53464)	1
#   (138493, 53996)	1
#   (138493, 55269)	1
#   (138493, 55814)	1
#   (138493, 58879)	1
#   (138493, 59315)	1
#   (138493, 59784)	1
#   (138493, 60069)	1
#   (138493, 60816)	1
#   (138493, 61160)	1
#   (138493, 65682)	1
#   (138493, 66762)	1
#   (138493, 68319)	1
#   (138493, 68954)	1
#   (138493, 69526)	1
#   (138493, 70286)	1

# %%
model = AlternatingLeastSquares(
    factors=50,
    regularization=0.01,
    iterations=20
)

# implicit erwartet Item-User-Matrix
model.fit(user_item.T)
# Out:
# C:\Users\Tobis\Python\anaconda3\lib\site-packages\implicit\utils.py:164: ParameterWarning: Method expects CSR input, and was passed csc_matrix instead. Converting to CSR took 0.09774303436279297 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
user_idx = 1

ids, scores = model.recommend(
    userid=user_idx,
    user_items=user_item[user_idx],
    N=10
)
print(ids)
print(scores)
# Out:
# [110758  69603  55391  24219   7648  58346 119675 108773  23308 130710]
# [1.9181325 1.8945049 1.8882118 1.836183  1.7680337 1.763559  1.7502732
#  1.7411422 1.7391831 1.7308735]

# %%
movie_lookup = (
    df_movie[["movieId", "title"]]
    .drop_duplicates()
    .set_index("movieId")["title"]
    .to_dict()
)

for movie_id in ids:
    print(movie_id, "->", movie_lookup.get(movie_id, "nicht gefunden"))
# Out:
# 110758 -> nicht gefunden
# 69603 -> nicht gefunden
# 55391 -> 10th & Wolf (2006)
# 24219 -> nicht gefunden
# 7648 -> Wildflowers (1999)
# 58346 -> nicht gefunden
# 119675 -> nicht gefunden
# 108773 -> Come Live with Me (1941)
# 23308 -> nicht gefunden
# 130710 -> nicht gefunden

# %%
recommendations = pd.DataFrame({
    "movieId": movie_ids,
    "score": scores
})

recommendations = recommendations.merge(
    df_movie[["movieId", "title"]],
    on="movieId",
    how="left"
)

print(recommendations)
# Out:
#     movieId     score                                          title
# 0   65702.0  1.816650  War Comes to America (Why We Fight, 7) (1945)
# 1       NaN  1.794686                                            NaN
# 2       NaN  1.758287                                            NaN
# 3       NaN  1.754373                                            NaN
# 4   26996.0  1.749075                              Safe House (1998)
# 5  118902.0  1.730460                            Zebra Lounge (2001)
# 6       NaN  1.719097                                            NaN
# 7       NaN  1.713295                                            NaN
# 8       NaN  1.679129                                            NaN
# 9       NaN  1.673855                                            NaN

# %%
110758 in df_movie["movieId"].values
# Out:
# False
