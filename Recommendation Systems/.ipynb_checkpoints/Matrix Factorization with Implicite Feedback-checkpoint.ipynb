# %%
# %pip install implicit
# Out:
# Collecting implicit
#   Downloading implicit-0.7.3-cp39-cp39-win_amd64.whl (694 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (4.62.3)
# Requirement already satisfied: scipy>=0.16 in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (1.7.1)
# Requirement already satisfied: threadpoolctl in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (2.2.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\tobis\python\anaconda3\lib\site-packages (from implicit) (1.20.3)
# Requirement already satisfied: colorama in c:\users\tobis\python\anaconda3\lib\site-packages (from tqdm>=4.27->implicit) (0.4.4)
# Installing collected packages: implicit
# Successfully installed implicit-0.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import implicit as imp
from implicit.als import AlternatingLeastSquares
from scipy.sparse import csr_matrix

# %%
df_movie = pd.read_csv(r"C:\Users\Tobis\Desktop\Implicit Recommendation System\movie\movie.csv")
df_rating = pd.read_csv(r"C:\Users\Tobis\Desktop\Implicit Recommendation System\rating\rating.csv")

# %%
print(df_rating.head())
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
print(df_movie.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print(max(df_movie["movieId"]))
print(len(df_movie["movieId"]))
print(max(df_movie.index))
# Out:
# 131262
# 27278
# 27277

# %%
df_movie["movieId_index"] = df_movie.index
print(df_movie.head())
print(max(df_movie["movieId"]))
print(len(df_movie["movieId"]))
print(max(df_movie.index))
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  movieId_index
# 0  Adventure|Animation|Children|Comedy|Fantasy              0
# 1                   Adventure|Children|Fantasy              1
# 2                               Comedy|Romance              2
# 3                         Comedy|Drama|Romance              3
# 4                                       Comedy              4
# 131262
# 27278
# 27277

# %%
# New column "implicit" as positive feedback
df_rating["implicit"] = (df_rating["rating"] >= 4).astype(int)
print(df_rating.head(10))
# Out:
#    userId  movieId  rating            timestamp  implicit
# 0       1        2     3.5  2005-04-02 23:53:47         0
# 1       1       29     3.5  2005-04-02 23:31:16         0
# 2       1       32     3.5  2005-04-02 23:33:39         0
# 3       1       47     3.5  2005-04-02 23:32:07         0
# 4       1       50     3.5  2005-04-02 23:29:40         0
# 5       1      112     3.5  2004-09-10 03:09:00         0
# 6       1      151     4.0  2004-09-10 03:08:54         1
# 7       1      223     4.0  2005-04-02 23:46:13         1
# 8       1      253     4.0  2005-04-02 23:35:40         1
# 9       1      260     4.0  2005-04-02 23:33:46         1

# %%
df_joined = df_rating.merge(
    df_movie,
    on="movieId",
    how="left"
)

print(df_joined.head())
# Out:
#    userId  movieId  rating            timestamp  implicit  \
# 0       1        2     3.5  2005-04-02 23:53:47         0
# 1       1       29     3.5  2005-04-02 23:31:16         0
# 2       1       32     3.5  2005-04-02 23:33:39         0
# 3       1       47     3.5  2005-04-02 23:32:07         0
# 4       1       50     3.5  2005-04-02 23:29:40         0
#
#                                                title  \
# 0                                     Jumanji (1995)
# 1  City of Lost Children, The (Cité des enfants p...
# 2          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                        Seven (a.k.a. Se7en) (1995)
# 4                         Usual Suspects, The (1995)
#
#                                    genres  movieId_index
# 0              Adventure|Children|Fantasy              1
# 1  Adventure|Drama|Fantasy|Mystery|Sci-Fi             28
# 2                 Mystery|Sci-Fi|Thriller             31
# 3                        Mystery|Thriller             46
# 4                  Crime|Mystery|Thriller             49

# %%
print(df_joined)
# Out:
#           userId  movieId  rating            timestamp  implicit  \
# 0              1        2     3.5  2005-04-02 23:53:47         0
# 1              1       29     3.5  2005-04-02 23:31:16         0
# 2              1       32     3.5  2005-04-02 23:33:39         0
# 3              1       47     3.5  2005-04-02 23:32:07         0
# 4              1       50     3.5  2005-04-02 23:29:40         0
# ...          ...      ...     ...                  ...       ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00         1
# 20000259  138493    69526     4.5  2009-12-03 18:31:48         1
# 20000260  138493    69644     3.0  2009-12-07 18:10:57         0
# 20000261  138493    70286     5.0  2009-11-13 15:42:24         1
# 20000262  138493    71619     2.5  2009-10-17 20:25:36         0
#
#                                                       title  \
# 0                                            Jumanji (1995)
# 1         City of Lost Children, The (Cité des enfants p...
# 2                 Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                               Seven (a.k.a. Se7en) (1995)
# 4                                Usual Suspects, The (1995)
# ...                                                     ...
# 20000258                                          Up (2009)
# 20000259         Transformers: Revenge of the Fallen (2009)
# 20000260              Ice Age: Dawn of the Dinosaurs (2009)
# 20000261                                  District 9 (2009)
# 20000262      Coco Before Chanel (Coco avant Chanel) (2009)
#
#                                                      genres  movieId_index
# 0                                Adventure|Children|Fantasy              1
# 1                    Adventure|Drama|Fantasy|Mystery|Sci-Fi             28
# 2                                   Mystery|Sci-Fi|Thriller             31
# 3                                          Mystery|Thriller             46
# 4                                    Crime|Mystery|Thriller             49
# ...                                                     ...            ...
# 20000258                 Adventure|Animation|Children|Drama          13767
# 20000259                       Action|Adventure|Sci-Fi|IMAX          13876
# 20000260  Action|Adventure|Animation|Children|Comedy|Rom...          13890
# 20000261                            Mystery|Sci-Fi|Thriller          14009
# 20000262                                              Drama          14293
#
# [20000263 rows x 8 columns]

# %%
df_positive = df_joined[df_joined["implicit"] == 1].copy()

# %%
print(df_positive)
# Out:
#           userId  movieId  rating            timestamp  implicit  \
# 6              1      151     4.0  2004-09-10 03:08:54         1
# 7              1      223     4.0  2005-04-02 23:46:13         1
# 8              1      253     4.0  2005-04-02 23:35:40         1
# 9              1      260     4.0  2005-04-02 23:33:46         1
# 10             1      293     4.0  2005-04-02 23:31:43         1
# ...          ...      ...     ...                  ...       ...
# 20000256  138493    66762     4.5  2009-10-17 18:50:08         1
# 20000257  138493    68319     4.5  2009-12-07 18:15:20         1
# 20000258  138493    68954     4.5  2009-11-13 15:42:00         1
# 20000259  138493    69526     4.5  2009-12-03 18:31:48         1
# 20000261  138493    70286     5.0  2009-11-13 15:42:24         1
#
#                                                       title  \
# 6                                            Rob Roy (1995)
# 7                                             Clerks (1994)
# 8         Interview with the Vampire: The Vampire Chroni...
# 9                 Star Wars: Episode IV - A New Hope (1977)
# 10        Léon: The Professional (a.k.a. The Professiona...
# ...                                                     ...
# 20000256                                       Paris (2008)
# 20000257                    X-Men Origins: Wolverine (2009)
# 20000258                                          Up (2009)
# 20000259         Transformers: Revenge of the Fallen (2009)
# 20000261                                  District 9 (2009)
#
#                                       genres  movieId_index
# 6                   Action|Drama|Romance|War            149
# 7                                     Comedy            220
# 8                               Drama|Horror            250
# 9                    Action|Adventure|Sci-Fi            257
# 10               Action|Crime|Drama|Thriller            290
# ...                                      ...            ...
# 20000256                Comedy|Drama|Romance          13498
# 20000257              Action|Sci-Fi|Thriller          13677
# 20000258  Adventure|Animation|Children|Drama          13767
# 20000259        Action|Adventure|Sci-Fi|IMAX          13876
# 20000261             Mystery|Sci-Fi|Thriller          14009
#
# [9995410 rows x 8 columns]

# %%
#user_ids = df_rating["userId"].unique()
#movie_ids = df_rating["movieId"].unique()

#user_map = {u: i for i, u in enumerate(user_ids)}
#movie_map = {m: i for i, m in enumerate(movie_ids)}

#df_positive["user_idx"] = df_positive["userId"].map(user_map)
#df_positive["movie_idx"] = df_positive["movieId"].map(movie_map)

# %%
# Get User_Item matrix
user_item = csr_matrix(
    (
        df_positive["implicit"],
        (
            df_positive["userId"],
            df_positive["movieId_index"]
        )
    )
)
print(user_item)
# Out:
#   (1, 149)	1
#   (1, 220)	1
#   (1, 250)	1
#   (1, 257)	1
#   (1, 290)	1
#   (1, 293)	1
#   (1, 315)	1
#   (1, 537)	1
#   (1, 1017)	1
#   (1, 1057)	1
#   (1, 1068)	1
#   (1, 1075)	1
#   (1, 1171)	1
#   (1, 1173)	1
#   (1, 1175)	1
#   (1, 1188)	1
#   (1, 1189)	1
#   (1, 1193)	1
#   (1, 1212)	1
#   (1, 1221)	1
#   (1, 1230)	1
#   (1, 1231)	1
#   (1, 1238)	1
#   (1, 1250)	1
#   (1, 1292)	1
#   :	:
#   (138493, 11362)	1
#   (138493, 11401)	1
#   (138493, 11493)	1
#   (138493, 11707)	1
#   (138493, 11724)	1
#   (138493, 11804)	1
#   (138493, 11858)	1
#   (138493, 11872)	1
#   (138493, 11892)	1
#   (138493, 11911)	1
#   (138493, 11972)	1
#   (138493, 12139)	1
#   (138493, 12215)	1
#   (138493, 12565)	1
#   (138493, 12631)	1
#   (138493, 12691)	1
#   (138493, 12746)	1
#   (138493, 12875)	1
#   (138493, 12926)	1
#   (138493, 13358)	1
#   (138493, 13498)	1
#   (138493, 13677)	1
#   (138493, 13767)	1
#   (138493, 13876)	1
#   (138493, 14009)	1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here the confidence is calculated using the magnitude of r (the feedback data) giving us a larger confidence if a user has viewed an item. The rate of which our confidence increases is set through a linear scaling factor α. We also add 1 so we have a minimal confidence even if α x r equals zero.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Train ALS on User_Item matrix
model = AlternatingLeastSquares(
    factors=50,
    regularization=0.01,
    iterations=20
)

# implicit erwartet Item-User-Matrix
model.fit(user_item)
# Out:
# C:\Users\Tobis\Python\anaconda3\lib\site-packages\implicit\cpu\als.py:96: RuntimeWarning: Intel MKL BLAS is configured to use 6 threads. It is highly recommended to disable its internal threadpool by setting the environment variable 'MKL_NUM_THREADS=1' or by callng 'threadpoolctl.threadpool_limits(1, "blas")'. Having MKL use a threadpool can lead to severe performance issues
#   check_blas_config()
#   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# To calculate the similarity between items we compute the dot-product between our item vectors and it’s transpose.
#
# ![image-2.png](attachment:image-2.png)
#
# To make recommendations for a given user we take a similar approach. Here we calculate the dot product between our user vector and the transpose of our item vectors. This gives us a recommendation score for our user and each item:

# %%
# Recommendations
user_idx = 1

ids, scores = model.recommend(
    userid=user_idx,
    user_items=user_item[user_idx],
    N=10
)
print(ids)
print(scores)
# Out:
# [1172 1263 1067 1184 6764 1913   49 2486 6271 3702]
# [0.57840693 0.5754086  0.49884492 0.48755497 0.4764397  0.45259142
#  0.41701752 0.4105261  0.40532646 0.40000296]

# %%
# Lookup movies
movie_lookup = (
    df_movie[["movieId_index", "title"]]
    .drop_duplicates()
    .set_index("movieId_index")["title"]
    .to_dict()
)

for movie_id in ids:
    print(movie_id, "->", movie_lookup.get(movie_id, "nicht gefunden"))
# Out:
# 1172 -> Princess Bride, The (1987)
# 1263 -> Indiana Jones and the Last Crusade (1989)
# 1067 -> Reservoir Dogs (1992)
# 1184 -> Star Wars: Episode VI - Return of the Jedi (1983)
# 6764 -> Kill Bill: Vol. 1 (2003)
# 1913 -> Exorcist, The (1973)
# 49 -> Usual Suspects, The (1995)
# 2486 -> Matrix, The (1999)
# 6271 -> Finding Nemo (2003)
# 3702 -> X-Men (2000)

# %%
# This user has the following recommendations
recommendations = pd.DataFrame({
    "movieId_index": ids,
    "score": scores
})

recommendations = recommendations.merge(
    df_movie[["movieId_index", "title", "genres"]],
    on="movieId_index",
    how="left"
)

print(recommendations)
# Out:
#    movieId_index     score                                              title  \
# 0           1172  0.578407                         Princess Bride, The (1987)
# 1           1263  0.575409          Indiana Jones and the Last Crusade (1989)
# 2           1067  0.498845                              Reservoir Dogs (1992)
# 3           1184  0.487555  Star Wars: Episode VI - Return of the Jedi (1983)
# 4           6764  0.476440                           Kill Bill: Vol. 1 (2003)
# 5           1913  0.452591                               Exorcist, The (1973)
# 6             49  0.417018                         Usual Suspects, The (1995)
# 7           2486  0.410526                                 Matrix, The (1999)
# 8           6271  0.405326                                Finding Nemo (2003)
# 9           3702  0.400003                                       X-Men (2000)
#
#                                     genres
# 0  Action|Adventure|Comedy|Fantasy|Romance
# 1                         Action|Adventure
# 2                   Crime|Mystery|Thriller
# 3                  Action|Adventure|Sci-Fi
# 4                    Action|Crime|Thriller
# 5                           Horror|Mystery
# 6                   Crime|Mystery|Thriller
# 7                   Action|Sci-Fi|Thriller
# 8      Adventure|Animation|Children|Comedy
# 9                  Action|Adventure|Sci-Fi

# %%
# This user allready whatched the following movies aund rated them positive
df_user1 = df_positive[df_positive["userId"] == user_idx][["userId", "title", "genres"]]
print(df_user1.to_string())
# Out:
#      userId                                                                                           title                                               genres
# 6         1                                                                                  Rob Roy (1995)                             Action|Drama|Romance|War
# 7         1                                                                                   Clerks (1994)                                               Comedy
# 8         1                                       Interview with the Vampire: The Vampire Chronicles (1994)                                         Drama|Horror
# 9         1                                                       Star Wars: Episode IV - A New Hope (1977)                              Action|Adventure|Sci-Fi
# 10        1                                  Léon: The Professional (a.k.a. The Professional) (Léon) (1994)                          Action|Crime|Drama|Thriller
# 11        1                                                                             Pulp Fiction (1994)                          Comedy|Crime|Drama|Thriller
# 12        1                                                                Shawshank Redemption, The (1994)                                          Crime|Drama
# 15        1                                                                             Blade Runner (1982)                               Action|Sci-Fi|Thriller
# 22        1                                                                                 Die Hard (1988)                                Action|Crime|Thriller
# 23        1                                                                     Fish Called Wanda, A (1988)                                         Comedy|Crime
# 26        1                                                                                  Platoon (1986)                                            Drama|War
# 27        1                                                               E.T. the Extra-Terrestrial (1982)                                Children|Drama|Sci-Fi
# 30        1                                           Star Wars: Episode V - The Empire Strikes Back (1980)                              Action|Adventure|Sci-Fi
# 31        1                  Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)                                     Action|Adventure
# 32        1                                                                                   Aliens (1986)                       Action|Adventure|Horror|Sci-Fi
# 35        1                                                                                    Alien (1979)                                        Horror|Sci-Fi
# 36        1                                                                         Army of Darkness (1993)               Action|Adventure|Comedy|Fantasy|Horror
# 38        1                                                                                   Psycho (1960)                                         Crime|Horror
# 40        1                                                                          Terminator, The (1984)                               Action|Sci-Fi|Thriller
# 43        1                                                                Femme Nikita, La (Nikita) (1990)                        Action|Crime|Romance|Thriller
# 44        1                                                                             Shining, The (1980)                                               Horror
# 45        1                                                                              Stand by Me (1986)                                      Adventure|Drama
# 48        1                                                                               Unforgiven (1992)                                        Drama|Western
# 49        1                                                                       Young Frankenstein (1974)                                       Comedy|Fantasy
# 52        1                                                          American Werewolf in London, An (1981)                               Comedy|Horror|Thriller
# 53        1                                                                               Birds, The (1963)                                      Horror|Thriller
# 56        1                                                                              Sling Blade (1996)                                                Drama
# 58        1                                                          Star Trek II: The Wrath of Khan (1982)                     Action|Adventure|Sci-Fi|Thriller
# 59        1                                                                                     Jaws (1975)                                        Action|Horror
# 65        1                                                                                Labyrinth (1986)                            Adventure|Fantasy|Musical
# 68        1                                                                                     Dune (1984)                                     Adventure|Sci-Fi
# 69        1                                                                                   Splash (1984)                               Comedy|Fantasy|Romance
# 70        1                                                                           Dead Zone, The (1983)                                             Thriller
# 71        1                                                                           Watership Down (1978)           Adventure|Animation|Children|Drama|Fantasy
# 72        1                                                                        Dark Crystal, The (1982)                                    Adventure|Fantasy
# 73        1                                                                                   Legend (1985)                            Adventure|Fantasy|Romance
# 74        1                                                      Navigator: A Mediaeval Odyssey, The (1988)                             Adventure|Fantasy|Sci-Fi
# 75        1                                                                              Beetlejuice (1988)                                       Comedy|Fantasy
# 76        1                                                                                   Willow (1988)                             Action|Adventure|Fantasy
# 79        1                                                                               Thing, The (1982)                        Action|Horror|Sci-Fi|Thriller
# 80        1                                                                      Edward Scissorhands (1990)                                Drama|Fantasy|Romance
# 81        1                                                        Lock, Stock & Two Smoking Barrels (1998)                                Comedy|Crime|Thriller
# 82        1                                                Star Wars: Episode I - The Phantom Menace (1999)                              Action|Adventure|Sci-Fi
# 90        1                                                                         Sixth Sense, The (1999)                                 Drama|Horror|Mystery
# 92        1                                                                                Excalibur (1981)                                    Adventure|Fantasy
# 94        1                                                                         Dirty Dozen, The (1967)                                     Action|Drama|War
# 96        1                                                                               Fight Club (1999)                          Action|Crime|Drama|Thriller
# 97        1                                                                             Time Bandits (1981)                      Adventure|Comedy|Fantasy|Sci-Fi
# 101       1                                                                            Sleepy Hollow (1999)                       Fantasy|Horror|Mystery|Romance
# 102       1                                                                7th Voyage of Sinbad, The (1958)                             Action|Adventure|Fantasy
# 106       1                                                                                Ladyhawke (1985)                            Adventure|Fantasy|Romance
# 107       1                                                                                     Hook (1991)                             Adventure|Comedy|Fantasy
# 108       1                                                                                   Misery (1990)                                Drama|Horror|Thriller
# 109       1                                                      Highlander: Endgame (Highlander IV) (2000)                             Action|Adventure|Fantasy
# 111       1                                         Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)                                 Action|Drama|Romance
# 113       1                                                                                   Snatch (2000)                                Comedy|Crime|Thriller
# 114       1                                                               O Brother, Where Art Thou? (2000)                               Adventure|Comedy|Crime
# 116       1                                                                           Lost Boys, The (1987)                               Comedy|Horror|Thriller
# 119       1                                                                                    Shrek (2001)  Adventure|Animation|Children|Comedy|Fantasy|Romance
# 121       1                                                      Adventures of Baron Munchausen, The (1988)                             Adventure|Comedy|Fantasy
# 122       1                                                         Bill & Ted's Excellent Adventure (1989)                              Adventure|Comedy|Sci-Fi
# 124       1                                                                          Wicker Man, The (1973)                        Drama|Horror|Mystery|Thriller
# 126       1  Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)                           Adventure|Children|Fantasy
# 127       1                                                                              Jabberwocky (1977)                             Adventure|Comedy|Fantasy
# 131       1                                       Lord of the Rings: The Fellowship of the Ring, The (2001)                                    Adventure|Fantasy
# 132       1                                            Brotherhood of the Wolf (Pacte des loups, Le) (2001)                              Action|Mystery|Thriller
# 133       1                                                                             Dragonslayer (1981)                             Action|Adventure|Fantasy
# 136       1                                                                        Time Machine, The (2002)                              Action|Adventure|Sci-Fi
# 137       1                                                                      Clash of the Titans (1981)                     Action|Adventure|Fantasy|Romance
# 139       1                                                                   Company of Wolves, The (1984)                                       Fantasy|Horror
# 140       1                                                  Harry Potter and the Chamber of Secrets (2002)                                    Adventure|Fantasy
# 142       1                                                   Lord of the Rings: The Two Towers, The (2002)                                    Adventure|Fantasy
# 144       1                                                                        Last Unicorn, The (1982)                           Animation|Children|Fantasy
# 146       1                                                                         X2: X-Men United (2003)                     Action|Adventure|Sci-Fi|Thriller
# 148       1                                   Pirates of the Caribbean: The Curse of the Black Pearl (2003)                      Action|Adventure|Comedy|Fantasy
# 149       1                                                                               Underworld (2003)                                Action|Fantasy|Horror
# 151       1                                                                               Videodrome (1983)                       Fantasy|Horror|Sci-Fi|Thriller
# 157       1                                                                 Witches of Eastwick, The (1987)                       Comedy|Fantasy|Horror|Thriller
# 158       1                                           Lord of the Rings: The Return of the King, The (2003)                       Action|Adventure|Drama|Fantasy
# 162       1                                                                   One Million Years B.C. (1966)                                    Adventure|Fantasy
# 163       1                                                                        Kill Bill: Vol. 2 (2004)                                Action|Drama|Thriller
# 165       1                                                                              Van Helsing (2004)                      Action|Adventure|Fantasy|Horror
# 167       1                                                                  Jason and the Argonauts (1963)                             Action|Adventure|Fantasy
# 168       1                                                 Harry Potter and the Prisoner of Azkaban (2004)                               Adventure|Fantasy|IMAX
# 170       1                                                                                   Freaks (1932)                                   Crime|Drama|Horror
# 171       1                                                                             Spider-Man 2 (2004)                         Action|Adventure|Sci-Fi|IMAX
# 173       1                                                                         Incredibles, The (2004)           Action|Adventure|Animation|Children|Comedy
# 174       1                                                                              Constantine (2005)                       Action|Fantasy|Horror|Thriller
